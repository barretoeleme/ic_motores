# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
methods = ['linear', 
           'reg_tree', 
           'rand_for', 
           'catboost', 
           'xgboost']
variables = ['hysteresis',
             'joule']
datas = ['y_test',
         'y_pred']

index = pd.MultiIndex.from_product([methods, variables], names = ['method', 'variable'])
columns = pd.Index(datas, name = 'data')

# %%
df_2D = pd.DataFrame(index = index, columns = columns)


df_2D.loc[('linear', 'hysteresis'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/2D/hysteresis/pred_lin_reg.csv")['y_test'])
df_2D.loc[('linear', 'hysteresis'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/2D/hysteresis/pred_lin_reg.csv")['y_pred'])
df_2D.loc[('linear', 'joule'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/2D/joule/pred_lin_reg.csv")['y_test'])
df_2D.loc[('linear', 'joule'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/2D/joule/pred_lin_reg.csv")['y_pred'])

df_2D.loc[('reg_tree', 'hysteresis'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/2D/hysteresis/pred_reg_tree.csv")['y_test'])
df_2D.loc[('reg_tree', 'hysteresis'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/2D/hysteresis/pred_reg_tree.csv")['y_pred'])
df_2D.loc[('reg_tree', 'joule'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/2D/joule/pred_reg_tree.csv")['y_test'])
df_2D.loc[('reg_tree', 'joule'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/2D/joule/pred_reg_tree.csv")['y_pred'])

df_2D.loc[('rand_for', 'hysteresis'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/2D/hysteresis/pred_rand_for.csv")['y_test'])
df_2D.loc[('rand_for', 'hysteresis'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/2D/hysteresis/pred_rand_for.csv")['y_pred'])
df_2D.loc[('rand_for', 'joule'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/2D/joule/pred_rand_for.csv")['y_test'])
df_2D.loc[('rand_for', 'joule'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/2D/joule/pred_rand_for.csv")['y_pred'])

df_2D.loc[('catboost', 'hysteresis'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/2D/hysteresis/pred_catboost.csv")['y_test'])
df_2D.loc[('catboost', 'hysteresis'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/2D/hysteresis/pred_catboost.csv")['y_pred'])
df_2D.loc[('catboost', 'joule'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/2D/joule/pred_catboost.csv")['y_test'])
df_2D.loc[('catboost', 'joule'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/2D/joule/pred_catboost.csv")['y_pred'])

df_2D.loc[('xgboost', 'hysteresis'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/2D/hysteresis/pred_xgboost.csv")['y_test'])
df_2D.loc[('xgboost', 'hysteresis'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/2D/hysteresis/pred_xgboost.csv")['y_pred'])
df_2D.loc[('xgboost', 'joule'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/2D/joule/pred_xgboost.csv")['y_test'])
df_2D.loc[('xgboost', 'joule'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/2D/joule/pred_xgboost.csv")['y_pred'])


df_2D
# Out:
# data                                                            y_test  \
# method   variable
# linear   hysteresis  [2.181534224, 0.251901284, 1.670742534, -1.176...
#          joule       [2.063164189, 0.871329726, 1.56527343, -1.0499...
# reg_tree hysteresis  [2.181534224, 0.251901284, 1.670742534, -1.176...
#          joule       [2.063164189, 0.871329726, 1.56527343, -1.0499...
# rand_for hysteresis  [2.181534224, 0.251901284, 1.670742534, -1.176...
#          joule       [2.063164189, 0.871329726, 1.56527343, -1.0499...
# catboost hysteresis  [2.181534224, 0.251901284, 1.670742534, -1.176...
#          joule       [2.063164189, 0.871329726, 1.56527343, -1.0499...
# xgboost  hysteresis  [2.181534224, 0.251901284, 1.670742534, -1.176...
#          joule       [2.063164189, 0.871329726, 1.56527343, -1.0499...
#
# data                                                            y_pred
# method   variable
# linear   hysteresis  [1.5020883257423097, 0.3548746950668103, 1.173...
# ...

# %%
df_Nabla = pd.DataFrame(index = index, columns = columns)


df_Nabla.loc[('linear', 'hysteresis'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/Nabla/hysteresis/pred_lin_reg.csv")['y_test'])
df_Nabla.loc[('linear', 'hysteresis'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/Nabla/hysteresis/pred_lin_reg.csv")['y_pred'])
df_Nabla.loc[('linear', 'joule'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/Nabla/joule/pred_lin_reg.csv")['y_test'])
df_Nabla.loc[('linear', 'joule'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/Nabla/joule/pred_lin_reg.csv")['y_pred'])

df_Nabla.loc[('reg_tree', 'hysteresis'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/Nabla/hysteresis/pred_reg_tree.csv")['y_test'])
df_Nabla.loc[('reg_tree', 'hysteresis'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/Nabla/hysteresis/pred_reg_tree.csv")['y_pred'])
df_Nabla.loc[('reg_tree', 'joule'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/Nabla/joule/pred_reg_tree.csv")['y_test'])
df_Nabla.loc[('reg_tree', 'joule'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/Nabla/joule/pred_reg_tree.csv")['y_pred'])

df_Nabla.loc[('rand_for', 'hysteresis'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/Nabla/hysteresis/pred_rand_for.csv")['y_test'])
df_Nabla.loc[('rand_for', 'hysteresis'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/Nabla/hysteresis/pred_rand_for.csv")['y_pred'])
df_Nabla.loc[('rand_for', 'joule'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/Nabla/joule/pred_rand_for.csv")['y_test'])
df_Nabla.loc[('rand_for', 'joule'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/Nabla/joule/pred_rand_for.csv")['y_pred'])

df_Nabla.loc[('catboost', 'hysteresis'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/Nabla/hysteresis/pred_catboost.csv")['y_test'])
df_Nabla.loc[('catboost', 'hysteresis'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/Nabla/hysteresis/pred_catboost.csv")['y_pred'])
df_Nabla.loc[('catboost', 'joule'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/Nabla/joule/pred_catboost.csv")['y_test'])
df_Nabla.loc[('catboost', 'joule'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/Nabla/joule/pred_catboost.csv")['y_pred'])

df_Nabla.loc[('xgboost', 'hysteresis'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/Nabla/hysteresis/pred_xgboost.csv")['y_test'])
df_Nabla.loc[('xgboost', 'hysteresis'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/Nabla/hysteresis/pred_xgboost.csv")['y_pred'])
df_Nabla.loc[('xgboost', 'joule'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/Nabla/joule/pred_xgboost.csv")['y_test'])
df_Nabla.loc[('xgboost', 'joule'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/Nabla/joule/pred_xgboost.csv")['y_pred'])


df_Nabla
# Out:
# data                                                            y_test  \
# method   variable
# linear   hysteresis  [-0.45047362, -0.39340576, -0.268259635, -0.24...
#          joule       [-0.677634963, -0.496937632, -0.668099394, -0....
# reg_tree hysteresis  [-0.45047362, -0.39340576, -0.268259635, -0.24...
#          joule       [-0.677634963, -0.496937632, -0.668099394, -0....
# rand_for hysteresis  [-0.45047362, -0.39340576, -0.268259635, -0.24...
#          joule       [-0.677634963, -0.496937632, -0.668099394, -0....
# catboost hysteresis  [-0.45047362, -0.39340576, -0.268259635, -0.24...
#          joule       [-0.677634963, -0.496937632, -0.668099394, -0....
# xgboost  hysteresis  [-0.45047362, -0.39340576, -0.268259635, -0.24...
#          joule       [-0.677634963, -0.496937632, -0.668099394, -0....
#
# data                                                            y_pred
# method   variable
# linear   hysteresis  [-0.444209963054785, -0.3040608908999796, 0.06...
# ...

# %%
df_V = pd.DataFrame(index = index, columns = columns)


df_V.loc[('linear', 'hysteresis'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/V/hysteresis/pred_lin_reg.csv")['y_test'])
df_V.loc[('linear', 'hysteresis'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/V/hysteresis/pred_lin_reg.csv")['y_pred'])
df_V.loc[('linear', 'joule'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/V/joule/pred_lin_reg.csv")['y_test'])
df_V.loc[('linear', 'joule'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/V/joule/pred_lin_reg.csv")['y_pred'])

df_V.loc[('reg_tree', 'hysteresis'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/V/hysteresis/pred_reg_tree.csv")['y_test'])
df_V.loc[('reg_tree', 'hysteresis'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/V/hysteresis/pred_reg_tree.csv")['y_pred'])
df_V.loc[('reg_tree', 'joule'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/V/joule/pred_reg_tree.csv")['y_test'])
df_V.loc[('reg_tree', 'joule'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/V/joule/pred_reg_tree.csv")['y_pred'])

df_V.loc[('rand_for', 'hysteresis'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/V/hysteresis/pred_rand_for.csv")['y_test'])
df_V.loc[('rand_for', 'hysteresis'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/V/hysteresis/pred_rand_for.csv")['y_pred'])
df_V.loc[('rand_for', 'joule'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/V/joule/pred_rand_for.csv")['y_test'])
df_V.loc[('rand_for', 'joule'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/V/joule/pred_rand_for.csv")['y_pred'])

df_V.loc[('catboost', 'hysteresis'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/V/hysteresis/pred_catboost.csv")['y_test'])
df_V.loc[('catboost', 'hysteresis'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/V/hysteresis/pred_catboost.csv")['y_pred'])
df_V.loc[('catboost', 'joule'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/V/joule/pred_catboost.csv")['y_test'])
df_V.loc[('catboost', 'joule'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/V/joule/pred_catboost.csv")['y_pred'])

df_V.loc[('xgboost', 'hysteresis'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/V/hysteresis/pred_xgboost.csv")['y_test'])
df_V.loc[('xgboost', 'hysteresis'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/V/hysteresis/pred_xgboost.csv")['y_pred'])
df_V.loc[('xgboost', 'joule'), 'y_test'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/V/joule/pred_xgboost.csv")['y_test'])
df_V.loc[('xgboost', 'joule'), 'y_pred'] = np.array(pd.read_csv("/mnt/c/prog/IniciacaoCientifica/pred/V/joule/pred_xgboost.csv")['y_pred'])


df_V
# Out:
# data                                                            y_test  \
# method   variable
# linear   hysteresis  [0.425989021, 0.102374513, 1.204757692, 0.5290...
#          joule       [-0.049670878, -0.294774154, 0.74449388, 1.238...
# reg_tree hysteresis  [0.425989021, 0.102374513, 1.204757692, 0.5290...
#          joule       [-0.049670878, -0.294774154, 0.74449388, 1.238...
# rand_for hysteresis  [0.425989021, 0.102374513, 1.204757692, 0.5290...
#          joule       [-0.049670878, -0.294774154, 0.74449388, 1.238...
# catboost hysteresis  [0.425989021, 0.102374513, 1.204757692, 0.5290...
#          joule       [-0.049670878, -0.294774154, 0.74449388, 1.238...
# xgboost  hysteresis  [0.425989021, 0.102374513, 1.204757692, 0.5290...
#          joule       [-0.049670878, -0.294774154, 0.74449388, 1.238...
#
# data                                                            y_pred
# method   variable
# linear   hysteresis  [0.3557118562085226, 0.1586693583651705, 1.175...
# ...

# %%
# true_value = df_2D.loc[('linear', 'hysteresis'), 'y_test']
# predicted_value = df_2D.loc[('linear', 'hysteresis'), 'y_pred']

def obs_vs_pred (true_value, predicted_value, title):
    plt.figure(figsize=(7, 7))
    plt.scatter(true_value, predicted_value, c='crimson')
    
    p1 = max(max(predicted_value), max(true_value))
    p2 = min(min(predicted_value), min(true_value))
    plt.plot([p1, p2], [p1, p2], 'b-')
    plt.xlim(-3, 5)
    plt.ylim(-3, 5)
    plt.xlabel('True Values', fontsize=15)
    plt.ylabel('Predictions', fontsize=15)
    plt.title(title, fontsize = 18)
    plt.show()

# %%
obs_vs_pred(df_2D.loc[('linear', 'hysteresis'), 'y_test'], df_2D.loc[('linear', 'hysteresis'), 'y_pred'], "Motor 2D - linear regression - hysteresis loss")
obs_vs_pred(df_2D.loc[('linear', 'joule'), 'y_test'], df_2D.loc[('linear', 'joule'), 'y_pred'], "Motor 2D - linear regression - joule loss")

obs_vs_pred(df_2D.loc[('reg_tree', 'hysteresis'), 'y_test'], df_2D.loc[('reg_tree', 'hysteresis'), 'y_pred'], "Motor 2D - decision tree - hysteresis loss")
obs_vs_pred(df_2D.loc[('reg_tree', 'joule'), 'y_test'], df_2D.loc[('reg_tree', 'joule'), 'y_pred'], "Motor 2D - decision tree - joule loss")

obs_vs_pred(df_2D.loc[('rand_for', 'hysteresis'), 'y_test'], df_2D.loc[('rand_for', 'hysteresis'), 'y_pred'], "Motor 2D - random forest - hysteresis loss")
obs_vs_pred(df_2D.loc[('rand_for', 'joule'), 'y_test'], df_2D.loc[('rand_for', 'joule'), 'y_pred'], "Motor 2D - random forest - joule loss")

obs_vs_pred(df_2D.loc[('catboost', 'hysteresis'), 'y_test'], df_2D.loc[('catboost', 'hysteresis'), 'y_pred'], "Motor 2D - catboost - hysteresis loss")
obs_vs_pred(df_2D.loc[('catboost', 'joule'), 'y_test'], df_2D.loc[('catboost', 'joule'), 'y_pred'], "Motor 2D - catboost - joule loss")

obs_vs_pred(df_2D.loc[('xgboost', 'hysteresis'), 'y_test'], df_2D.loc[('xgboost', 'hysteresis'), 'y_pred'], "Motor 2D - xgboost - hysteresis loss")
obs_vs_pred(df_2D.loc[('xgboost', 'joule'), 'y_test'], df_2D.loc[('xgboost', 'joule'), 'y_pred'], "Motor 2D - xgboost - joule loss")

# %%
obs_vs_pred(df_Nabla.loc[('linear', 'hysteresis'), 'y_test'], df_Nabla.loc[('linear', 'hysteresis'), 'y_pred'], "Motor Nabla - linear regression - hysteresis loss")
obs_vs_pred(df_Nabla.loc[('linear', 'joule'), 'y_test'], df_Nabla.loc[('linear', 'joule'), 'y_pred'], "Motor Nabla - linear regression - joule loss")

obs_vs_pred(df_Nabla.loc[('reg_tree', 'hysteresis'), 'y_test'], df_Nabla.loc[('reg_tree', 'hysteresis'), 'y_pred'], "Motor Nabla - decision tree - hysteresis loss")
obs_vs_pred(df_Nabla.loc[('reg_tree', 'joule'), 'y_test'], df_Nabla.loc[('reg_tree', 'joule'), 'y_pred'], "Motor Nabla - decision tree - joule loss")

obs_vs_pred(df_Nabla.loc[('rand_for', 'hysteresis'), 'y_test'], df_Nabla.loc[('rand_for', 'hysteresis'), 'y_pred'], "Motor Nabla - random forest - hysteresis loss")
obs_vs_pred(df_Nabla.loc[('rand_for', 'joule'), 'y_test'], df_Nabla.loc[('rand_for', 'joule'), 'y_pred'], "Motor Nabla - random forest - joule loss")

obs_vs_pred(df_Nabla.loc[('catboost', 'hysteresis'), 'y_test'], df_Nabla.loc[('catboost', 'hysteresis'), 'y_pred'], "Motor Nabla - catboost - hysteresis loss")
obs_vs_pred(df_Nabla.loc[('catboost', 'joule'), 'y_test'], df_Nabla.loc[('catboost', 'joule'), 'y_pred'], "Motor Nabla - catboost - joule loss")

obs_vs_pred(df_Nabla.loc[('xgboost', 'hysteresis'), 'y_test'], df_Nabla.loc[('xgboost', 'hysteresis'), 'y_pred'], "Motor Nabla - xgboost - hysteresis loss")
obs_vs_pred(df_Nabla.loc[('xgboost', 'joule'), 'y_test'], df_Nabla.loc[('xgboost', 'joule'), 'y_pred'], "Motor Nabla - xgboost - joule loss")

# %%
obs_vs_pred(df_V.loc[('linear', 'hysteresis'), 'y_test'], df_V.loc[('linear', 'hysteresis'), 'y_pred'], "Motor V - linear regression - hysteresis loss")
obs_vs_pred(df_V.loc[('linear', 'joule'), 'y_test'], df_V.loc[('linear', 'joule'), 'y_pred'], "Motor V - linear regression - joule loss")

obs_vs_pred(df_V.loc[('reg_tree', 'hysteresis'), 'y_test'], df_V.loc[('reg_tree', 'hysteresis'), 'y_pred'], "Motor V - decision tree - hysteresis loss")
obs_vs_pred(df_V.loc[('reg_tree', 'joule'), 'y_test'], df_V.loc[('reg_tree', 'joule'), 'y_pred'], "Motor V - decision tree - joule loss")

obs_vs_pred(df_V.loc[('rand_for', 'hysteresis'), 'y_test'], df_V.loc[('rand_for', 'hysteresis'), 'y_pred'], "Motor V - random forest - hysteresis loss")
obs_vs_pred(df_V.loc[('rand_for', 'joule'), 'y_test'], df_V.loc[('rand_for', 'joule'), 'y_pred'], "Motor V - random forest - joule loss")

obs_vs_pred(df_V.loc[('catboost', 'hysteresis'), 'y_test'], df_V.loc[('catboost', 'hysteresis'), 'y_pred'], "Motor V - catboost - hysteresis loss")
obs_vs_pred(df_V.loc[('catboost', 'joule'), 'y_test'], df_V.loc[('catboost', 'joule'), 'y_pred'], "Motor V - catboost - joule loss")

obs_vs_pred(df_V.loc[('xgboost', 'hysteresis'), 'y_test'], df_V.loc[('xgboost', 'hysteresis'), 'y_pred'], "Motor V - xgboost - hysteresis loss")
obs_vs_pred(df_V.loc[('xgboost', 'joule'), 'y_test'], df_V.loc[('xgboost', 'joule'), 'y_pred'], "Motor V - xgboost - joule loss")
