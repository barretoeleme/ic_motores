# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
methods = ['cat_rand', 
           'xgb_rand']
variables = ['hysteresis',
             'joule']
metrics = ['score', 
           'mse',
           'mape']

index = pd.MultiIndex.from_product([methods, variables], names = ['method', 'variable'])
columns = pd.Index(metrics, name = 'metric')

# %%
df_2D = pd.DataFrame(index = index, columns = columns)

#df_2D.loc[('cat_rand', 'hysteresis')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/2D/hysteresis/results_cat_rand.csv").iloc[0]
#df_2D.loc[('cat_rand', 'hysteresis')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/2D/hysteresis/results_cat_rand.csv").iloc[0]
#df_2D.loc[('cat_rand', 'joule')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/2D/joule/results_cat_rand.csv").iloc[0]
#df_2D.loc[('cat_rand', 'joule')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/2D/joule/results_cat_rand.csv").iloc[0]

df_2D.loc[('xgb_rand', 'hysteresis')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/2D/hysteresis/results_xgb_rand.csv").iloc[0]
df_2D.loc[('xgb_rand', 'hysteresis')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/2D/hysteresis/results_xgb_rand.csv").iloc[0]
df_2D.loc[('xgb_rand', 'joule')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/2D/joule/results_xgb_rand.csv").iloc[0]
df_2D.loc[('xgb_rand', 'joule')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/2D/joule/results_xgb_rand.csv").iloc[0]

df_2D
# Out:
# metric                  score       mse      mape
# method   variable
# cat_rand hysteresis       NaN       NaN       NaN
#          joule            NaN       NaN       NaN
# xgb_rand hysteresis  0.980901  0.019471  0.178209
#          joule       0.833522  0.191739  0.217464

# %%
df_Nabla = pd.DataFrame(index = index, columns = columns)

#df_Nabla.loc[('cat_rand', 'hysteresis')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/Nabla/hysteresis/results_cat_rand.csv").iloc[0]
#df_Nabla.loc[('cat_rand', 'hysteresis')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/Nabla/hysteresis/results_cat_rand.csv").iloc[0]
#df_Nabla.loc[('cat_rand', 'joule')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/Nabla/joule/results_cat_rand.csv").iloc[0]
#df_Nabla.loc[('cat_rand', 'joule')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/Nabla/joule/results_cat_rand.csv").iloc[0]

df_Nabla.loc[('xgb_rand', 'hysteresis')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/Nabla/hysteresis/results_xgb_rand.csv").iloc[0]
df_Nabla.loc[('xgb_rand', 'hysteresis')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/Nabla/hysteresis/results_xgb_rand.csv").iloc[0]
df_Nabla.loc[('xgb_rand', 'joule')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/Nabla/joule/results_xgb_rand.csv").iloc[0]
df_Nabla.loc[('xgb_rand', 'joule')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/Nabla/joule/results_xgb_rand.csv").iloc[0]

df_Nabla
# Out:
# metric                  score       mse      mape
# method   variable
# cat_rand hysteresis       NaN       NaN       NaN
#          joule            NaN       NaN       NaN
# xgb_rand hysteresis  0.993701  0.006139  0.891864
#          joule       0.987984  0.011726  0.298276

# %%
df_V = pd.DataFrame(index = index, columns = columns)

#df_V.loc[('cat_rand', 'hysteresis')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/V/hysteresis/results_cat_rand.csv").iloc[0]
#df_V.loc[('cat_rand', 'hysteresis')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/V/hysteresis/results_cat_rand.csv").iloc[0]
#df_V.loc[('cat_rand', 'joule')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/V/joule/results_cat_rand.csv").iloc[0]
#df_V.loc[('cat_rand', 'joule')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/V/joule/results_cat_rand.csv").iloc[0]

df_V.loc[('xgb_rand', 'hysteresis')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/V/hysteresis/results_xgb_rand.csv").iloc[0]
df_V.loc[('xgb_rand', 'hysteresis')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/V/hysteresis/results_xgb_rand.csv").iloc[0]
df_V.loc[('xgb_rand', 'joule')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/V/joule/results_xgb_rand.csv").iloc[0]
df_V.loc[('xgb_rand', 'joule')] = pd.read_csv("/mnt/c/prog/ic_motores/IniciacaoCientifica/results/V/joule/results_xgb_rand.csv").iloc[0]

df_V
# Out:
# metric                  score       mse      mape
# method   variable
# cat_rand hysteresis       NaN       NaN       NaN
#          joule            NaN       NaN       NaN
# xgb_rand hysteresis  0.995912  0.004153  0.315962
#          joule       0.994688  0.005402  0.331223
